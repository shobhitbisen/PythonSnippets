# %% [markdown]
# <a href="https://colab.research.google.com/github/shobhitbisen/PythonSnippets/blob/master/my%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# word counter

# %%
# !wget https://www.dropbox.com/s/5vbyxqzj5xjkc3k/harpers_ASCII.txt
# Out:
# --2021-10-21 04:41:46--  https://www.dropbox.com/s/5vbyxqzj5xjkc3k/harpers_ASCII.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/5vbyxqzj5xjkc3k/harpers_ASCII.txt [following]
# --2021-10-21 04:41:46--  https://www.dropbox.com/s/raw/5vbyxqzj5xjkc3k/harpers_ASCII.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc97735cf6b05c46f93148c7a21a.dl.dropboxusercontent.com/cd/0/inline/BYYhtZhe8mp84qknYER8u7skimND7LI4TaKcJzuS1MuOCd0Nfwem8xof_r62JvXP26AfeNZedq2628CImbe2ITJPsSj8zbnXFD3DYYSaXzH0d6w2d3nqQHpBGkKe9D6IqNO0CZdVpeqpfrVn7BQWv_NE/file# [following]
# ...

# %%
f = open("/content/harpers_ASCII.txt","r")

# %%
c = []
for x in f:
    print(x)
    c.append(x.split(' '))
# Out:
# Streaming output truncated to the last 5000 lines.
# following one may not be amiss:
#
#
#
# A class of students, holding a grudge against one of the professors,
#
# tied a live goose to his chair. Upon entering the room the professor saw
#
# the goose, and calmly walking up to the desk, addressed the class as
#
# follows:
#
#
#
# "Gentlemen, as you have succeeded in getting an instructor so much
#
# better qualified to direct the bent of your ideas, I beg you will pardon
#
# me for resigning the chair."
#
#
#
#
#
#
#
#
#
# [Illustration: A BALLAD OF THE "CONSTITUTION"]
#
#
#
# BY ROWAN STEVENS.
#
#
#
#
#
#   _This is the tale that was told to me
#
#    _By a man with a tarry queue,
#
#   _Who sat with a spy-glass in his hand,
#
#    And gazed on the waters blue;
#
#   His hair was white, but his eye was bright,
#
#     And straight was his ancient form,
#
#   And his brown old face bore many a trace
#
#    Of the battle and the storm._
#
#
#
#
#
# I.
#
#
#
# ...

# %%
print(c)
# Out:
# [['Project', "Gutenberg's", "Harper's", 'Round', 'Table,', 'October', '8,', '1895,', 'by', 'Various\n'], ['\n'], ['This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with\n'], ['almost', 'no', 'restrictions', 'whatsoever.', '', 'You', 'may', 'copy', 'it,', 'give', 'it', 'away', 'or\n'], ['re-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included\n'], ['with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org\n'], ['\n'], ['\n'], ['Title:', "Harper's", 'Round', 'Table,', 'October', '8,', '1895\n'], ['\n'], ['Author:', 'Various\n'], ['\n'], ['Release', 'Date:', 'July', '14,', '2010', '[EBook', '#33158]\n'], ['\n'], ['Language:', 'English\n'], ['\n'], ['Character', 'set', 'encoding:', 'ASCII\n'], ['\n'], ['***', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', "HARPER'S", 'ROUND', 'TABLE', '***\n'], ['\n'], ['\n'], ['\n'], ['\n'], ['Produced', 'by', 'Annie', 'McGuire\n'], ['\n'], ['\n'
# ...

# %%
# c is the list of words
d=0
for i in range(len(c)):
  d=d+1
print(d)
# Out:
# 3939

# %%
len(c)
# Out:
# 3939

# %% [markdown]
# word game using python

# %%
def add(x,y):
       return x+y

def substract(x,y):
       return x-y

def multiply(x,y):
      return x*y

def division(x,y):
       return x/y

print("select operation.")
print("1.Add")
print("2.Substract")
print("3.Multiply")
print("4.Division")

while True:
      # take input from the user
      choice = input("Enter choice(1/2/3/4):")

      # check if choice is one of the four option
      if choice in ("1","2","3","4"):
           num1 = float(input("Enter first number:  "))
           num2 = float(input("Enter first number:  "))

           if choice == "1":
               print(num1 ,"+", num2 ,"=" ,add(num1,num2))

           elif choice == "2":
               print(num1 ,"-", num2 ,"=" ,substract(num1,num2))

           elif choice == "3":
               print(num1 ,"+" ,num2, "=" ,multiply(num1,num2))

           elif choice == "4":
               print(num1 ,"+", num2 ,"=" ,division(num1,num2))   
           break
      else:
           print("INVALID INPUT")
# Out:
# select operation.
# 1.Add
# 2.Substract
# 3.Multiply
# 4.Division
# Enter choice(1/2/3/4):4
# Enter first number:  55
# Enter first number:  11
# 55.0 + 11.0 = 5.0

# %% [markdown]
# uber data analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import os
import gc
import sys
from sklearn.linear_model import LogisticRegression,LinearRegression
# %matplotlib inline

# %%
# !wget https://www.dropbox.com/s/ncqb2ctkg7da11k/weather.csv
# Out:
# --2021-10-21 11:26:16--  https://www.dropbox.com/s/ncqb2ctkg7da11k/weather.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ncqb2ctkg7da11k/weather.csv [following]
# --2021-10-21 11:26:17--  https://www.dropbox.com/s/raw/ncqb2ctkg7da11k/weather.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc27fca39a85075b85f41b2685c4.dl.dropboxusercontent.com/cd/0/inline/BYeKmDu2RQ1OzBAx36Iki5_naBPjOsGOVYM7mMRAp-LBi6YPFt-TyE5qWWhzkkCWH6z1fxuuqLSI1xLYSvEkrEmmzpE6IZ0lPw6VP1LBbFSAOeGyHCzprsSAfUMux7pELfcYUEnJGYcxTueMgvzeBkGC/file# [following]
# ...

# %%
# !wget https://www.dropbox.com/s/brixkogrmhan6ed/cab_rides.csv
# Out:
# --2021-10-21 11:26:23--  https://www.dropbox.com/s/brixkogrmhan6ed/cab_rides.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/brixkogrmhan6ed/cab_rides.csv [following]
# --2021-10-21 11:26:23--  https://www.dropbox.com/s/raw/brixkogrmhan6ed/cab_rides.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucacb5c5c1439229d4fe17cc7fcb.dl.dropboxusercontent.com/cd/0/inline/BYcY4gwpFs7fL6zdvELcT6pOiRI640ICpxAmkG6SL9o_uLop2qnt6AfzZUR91XAc7PCBLhuIC4jCtlUsevnGAyXMg9wi_Ov5QAH06ZhnQKSdWrcsgrLbp5xKeiWD72EPJys5r_8brmBKb5C-YTHA7ylH/file# [following]
# ...

# %%
# memory saving function credit to https://www.kaggle.com/gemartin/load-data-reduce-memory-usage


def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df


def import_data(file):
    """create a dataframe and optimize its memory usage"""
    df = pd.read_csv(file, parse_dates=True, keep_date_col=True)
    df = reduce_mem_usage(df)
    return df

# %%
cab_data = pd.read_csv("/content/cab_rides.csv")
cab_data = reduce_mem_usage(cab_data)
weather_data = pd.read_csv("/content/weather.csv")
weather_data = reduce_mem_usage(weather_data)
# Out:
# Memory usage of dataframe is 52.88 MB
# Memory usage after optimization is: 40.49 MB
# Decreased by 23.4%
# Memory usage of dataframe is 0.38 MB
# Memory usage after optimization is: 0.10 MB
# Decreased by 73.3%

# %%
cab_data.head()
# Out:
#    distance cab_type  ...    product_id          name
# 0  0.439941     Lyft  ...     lyft_line        Shared
# 1  0.439941     Lyft  ...  lyft_premier           Lux
# 2  0.439941     Lyft  ...          lyft          Lyft
# 3  0.439941     Lyft  ...   lyft_luxsuv  Lux Black XL
# 4  0.439941     Lyft  ...     lyft_plus       Lyft XL
#
# [5 rows x 10 columns]

# %%
cab_data.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'datetime'],
#       dtype='object')

# %%
weather_data.head()
# Out:
#        temp            location  clouds  ...  time_stamp  humidity       wind
# 0  42.40625            Back Bay     1.0  ...  1545003901  0.770020  11.250000
# 1  42.43750         Beacon Hill     1.0  ...  1545003901  0.759766  11.320312
# 2  42.50000   Boston University     1.0  ...  1545003901  0.759766  11.070312
# 3  42.12500              Fenway     1.0  ...  1545003901  0.770020  11.093750
# 4  43.12500  Financial District     1.0  ...  1545003901  0.750000  11.492188
#
# [5 rows x 8 columns]

# %%
weather_data.columns
# Out:
# Index(['temp', 'location', 'clouds', 'pressure', 'rain', 'time_stamp',
#        'humidity', 'wind'],
#       dtype='object')

# %%
# for proper date time we chnage time_stamp into datetime

import datetime
cab_data['datetime'] = pd.to_datetime(cab_data['time_stamp'])
weather_data['datetime'] = pd.to_datetime(weather_data['time_stamp'])

# %%
cab_data.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'datetime'],
#       dtype='object')

# %%
weather_data.columns
# Out:
# Index(['temp', 'location', 'clouds', 'pressure', 'rain', 'time_stamp',
#        'humidity', 'wind', 'datetime'],
#       dtype='object')

# %%
cab_data.shape
# Out:
# (693071, 11)

# %%
weather_data.shape
# Out:
# (6276, 9)

# %%
cab_data.describe()
# Out:
#             distance    time_stamp     price  surge_multiplier
# count  693071.000000  6.930710e+05  637976.0          693071.0
# mean             NaN  1.544046e+12       NaN               NaN
# std         0.000000  6.891925e+08       0.0               0.0
# min         0.020004  1.543204e+12       2.5               1.0
# 25%         1.280273  1.543444e+12       9.0               1.0
# 50%         2.160156  1.543737e+12      13.5               1.0
# 75%         2.919922  1.544828e+12      22.5               1.0
# max         7.859375  1.545161e+12      97.5               3.0

# %%
weather_data.describe()
# Out:
#               temp       clouds  ...     humidity         wind
# count  6276.000000  6276.000000  ...  6276.000000  6276.000000
# mean           inf     0.677734  ...     0.764160     6.800781
# std       6.019531     0.314453  ...     0.127319     3.632812
# min      19.625000     0.000000  ...     0.449951     0.290039
# 25%      36.085938     0.439941  ...     0.669922     3.517090
# 50%      40.125000     0.779785  ...     0.759766     6.570312
# 75%      42.843750     0.970215  ...     0.890137     9.921875
# max      55.406250     1.000000  ...     0.990234    18.187500
#
# [8 rows x 7 columns]

# %%
# now for join the two data we used pd.concat function

a = pd.concat([cab_data,weather_data])

# %%
a.head()
# Out:
#    distance cab_type     time_stamp  ... rain humidity  wind
# 0  0.439941     Lyft  1544952607890  ...  NaN      NaN   NaN
# 1  0.439941     Lyft  1543284023677  ...  NaN      NaN   NaN
# 2  0.439941     Lyft  1543366822198  ...  NaN      NaN   NaN
# 3  0.439941     Lyft  1543553582749  ...  NaN      NaN   NaN
# 4  0.439941     Lyft  1543463360223  ...  NaN      NaN   NaN
#
# [5 rows x 18 columns]

# %%
a['day'] = a.datetime.dt.day
a['hour'] = a.datetime.dt.hour

# %%
a.head()
# Out:
#    distance cab_type     time_stamp    destination  ... humidity  wind  day hour
# 0  0.439941     Lyft  1544952607890  North Station  ...      NaN   NaN    1    0
# 1  0.439941     Lyft  1543284023677  North Station  ...      NaN   NaN    1    0
# 2  0.439941     Lyft  1543366822198  North Station  ...      NaN   NaN    1    0
# 3  0.439941     Lyft  1543553582749  North Station  ...      NaN   NaN    1    0
# 4  0.439941     Lyft  1543463360223  North Station  ...      NaN   NaN    1    0
#
# [5 rows x 20 columns]

# %%
a.tail()
# Out:
#       distance cab_type  time_stamp destination  ...  humidity      wind  day hour
# 6271       NaN      NaN  1543819974         NaN  ...  0.959961  1.519531    1    0
# 6272       NaN      NaN  1543819974         NaN  ...  0.959961  1.540039    1    0
# 6273       NaN      NaN  1543819974         NaN  ...  0.959961  1.540039    1    0
# 6274       NaN      NaN  1543819974         NaN  ...  0.959961  1.540039    1    0
# 6275       NaN      NaN  1543819974         NaN  ...  0.959961  1.519531    1    0
#
# [5 rows x 20 columns]

# %%
# we have lots of nan value but we dint want nan value for that we used  .fillna function to fill nan values

a.fillna(0,inplace=True)

# %%
a.head()
# Out:
#    distance cab_type     time_stamp    destination  ... humidity  wind  day hour
# 0  0.439941     Lyft  1544952607890  North Station  ...      0.0   0.0    1    0
# 1  0.439941     Lyft  1543284023677  North Station  ...      0.0   0.0    1    0
# 2  0.439941     Lyft  1543366822198  North Station  ...      0.0   0.0    1    0
# 3  0.439941     Lyft  1543553582749  North Station  ...      0.0   0.0    1    0
# 4  0.439941     Lyft  1543463360223  North Station  ...      0.0   0.0    1    0
#
# [5 rows x 20 columns]

# %%
a.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'datetime', 'temp',
#        'location', 'clouds', 'pressure', 'rain', 'humidity', 'wind', 'day',
#        'hour'],
#       dtype='object')

# %%
# groupby function it will return groups based on the column we provide, in thise data set we have "lyft and uber"

a.groupby('cab_type').count()
# Out:
#           distance  time_stamp  destination  ...    wind     day    hour
# cab_type                                     ...
# 0             6276        6276         6276  ...    6276    6276    6276
# Lyft        307408      307408       307408  ...  307408  307408  307408
# Uber        385663      385663       385663  ...  385663  385663  385663
#
# [3 rows x 19 columns]

# %%
a.groupby('cab_type').count().plot.bar()

# %%
a['price'].value_counts().plot(kind='bar',figsize=(100,50),color='blue')

# %%
a['hour'].value_counts().plot(kind='bar',figsize=(10,5),color='red')

# %%
import matplotlib.pyplot as plt
x = a['hour']
y = a['price']
plt.plot(x,y)
plt.show()

# %%
x = a['rain']
y = a['price']
plt.plot(x,y)
plt.show()

# %%
a.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'datetime', 'temp',
#        'location', 'clouds', 'pressure', 'rain', 'humidity', 'wind', 'day',
#        'hour'],
#       dtype='object')

# %%
x1 = a[['distance','datetime', 'pressure', 'rain', 'humidity', 'wind', 'day',
       'hour','surge_multiplier', 'clouds']]
y1 = a['price']

# %%
# using skicit-learn to split data into taining & testing sets
     from sklearn.family import model
     from sklearn.linear_model import LogisticRegression,LinearRegression

     from sklearn.model_selection import train_test_split
  
# split the data into training and testing sets

    x_train,y_train,x_test,y_test = train_test_split(x1,y1,test_size =0.25,random_state=42)

# %%
linear = LinearRegression()
linear = fit(x_train,x_test)

# %%
predictions = linear.predict(y_train)
predictions

# %%
df = pd.DataFrame({'Actual':y_test,
                                'predicted':predictions})
df
